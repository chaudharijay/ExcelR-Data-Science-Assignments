# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("exchange_rate.csv",parse_dates=['date'], dayfirst=True)

# %%
df.head()
# Out:
#         date  Ex_rate
# 0 1990-01-01   0.7855
# 1 1990-01-02   0.7818
# 2 1990-01-03   0.7867
# 3 1990-01-04   0.7860
# 4 1990-01-05   0.7849

# %%
df.shape
# Out:
# (7588, 2)

# %%
df.isna().sum()
# Out:
# date       0
# Ex_rate    0
# dtype: int64

# %%
df.describe()
# Out:
#                       date      Ex_rate
# count                 7588  7588.000000
# mean   2000-05-21 12:00:00     0.776974
# min    1990-01-01 00:00:00     0.483297
# 25%    1995-03-12 18:00:00     0.701422
# 50%    2000-05-21 12:00:00     0.761377
# 75%    2005-07-31 06:00:00     0.873477
# max    2010-10-10 00:00:00     1.102536
# std                    NaN     0.136620

# %%
df['Ex_rate'].describe()
# Out:
# count    7588.000000
# mean        0.776974
# std         0.136620
# min         0.483297
# 25%         0.701422
# 50%         0.761377
# 75%         0.873477
# max         1.102536
# Name: Ex_rate, dtype: float64

# %%
#line plot
plt.figure(figsize=(8,5))
plt.plot(df['date'],df['Ex_rate'],color='blue',label='USD TO AUD')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Exchange rates usd to austd')
plt.title('Exchange rate of us to australian')
plt.show()

# %%
#histogram
plt.figure(figsize=(8,5))
plt.hist(df['Ex_rate'],bins=50,color='pink',edgecolor='black')
plt.xlabel('Exchange rate')
plt.ylabel('Frequency')
plt.title('Distribution of exchange rates')
plt.tight_layout()
plt.show()

# %%
#box plot
plt.figure(figsize=(5,5))
plt.boxplot(df['Ex_rate'])
plt.xlabel('Exchange rate')
plt.title('Box plot of exchange rates')
plt.tight_layout()
plt.show()

# %%
df=pd.read_csv('exchange_rate.csv')
df.Ex_rate.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Moving avg plot

# %%
plt.figure(figsize=(12,4))
df.Ex_rate.plot().plot(label="org")
for i in range(2,24,6):
    df['Ex_rate'].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %% [markdown]
# ### Time Series Decomposition

# %%
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing # SES
from statsmodels.tsa.holtwinters import Holt # Holts Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
decompose_ts_add = seasonal_decompose(df.Ex_rate,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# ### ACF and PACF plots

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(df.Ex_rate)
tsa_plots.plot_pacf(df.Ex_rate)
plt.show()

# %% [markdown]
# ### converting non-stationary to stationary

# %%
df['Ex_rate_diff'] = df['Ex_rate'].diff()
df['Ex_rate_diff']
# Out:
# 0            NaN
# 1      -0.003700
# 2       0.004900
# 3      -0.000700
# 4      -0.001100
#           ...
# 7583   -0.000207
# 7584    0.003345
# 7585    0.001358
# 7586   -0.002372
# 7587    0.000000
# Name: Ex_rate_diff, Length: 7588, dtype: float64

# %%
df.isna().sum()
# Out:
# date            0
# Ex_rate         0
# Ex_rate_diff    1
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                date  Ex_rate  Ex_rate_diff
# 1  02-01-1990 00:00   0.7818       -0.0037
# 2  03-01-1990 00:00   0.7867        0.0049
# 3  04-01-1990 00:00   0.7860       -0.0007
# 4  05-01-1990 00:00   0.7849       -0.0011
# 5  06-01-1990 00:00   0.7866        0.0017

# %%
df.isna().sum()
# Out:
# date            0
# Ex_rate         0
# Ex_rate_diff    0
# dtype: int64

# %% [markdown]
# ### Checking if the data is stationary or not by plots

# %%
plt.plot(df['Ex_rate_diff'])
plt.show()

# %%
rolling_mean = df['Ex_rate_diff'].rolling(window=12).mean()
rolling_std = df['Ex_rate_diff'].rolling(window=12).std()
plt.plot(df['Ex_rate_diff'], label='Original')
plt.plot(rolling_mean, label='Rolling Mean')
plt.plot(rolling_std, label='Rolling Std')
plt.legend(loc='best')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df['Ex_rate_diff'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -99.39343120118623
# p-value: 0.0

# %% [markdown]
# ###Plotting the graph with pandas auto correlation plot to show the difference between the stationary data and non - stationary data

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
fig , (ax1,ax2) = plt.subplots(nrows = 2 ,ncols = 1,sharex = False , sharey = False , figsize = (10,5))
ax1 = autocorrelation_plot(df['Ex_rate_diff'], ax = ax1)
ax1.set_title('Non-Stationary Data')
df1 = df['Ex_rate_diff'].diff().dropna()
ax2 = autocorrelation_plot(df1 , ax = ax2)
ax2.set_title('Stationary Data')
plt.subplots_adjust(hspace = 0.5)
plt.savefig('Stationary data and Non-Stationary data.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a time series with a trend
time = np.arange(0, 100)
trend = 0.1 * time
non_stationary_data = np.sin(time) + trend

# Plot the non-stationary data
plt.plot(time, non_stationary_data, label='Non-Stationary')
plt.title('Non-Stationary Time Series')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Generate a stationary time series
stationary_data = np.sin(time)

# Plot the stationary data
plt.plot(time, stationary_data, label='Stationary')
plt.title('Stationary Time Series')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading Cython-3.0.11-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (69.5.1)
# Requirement already satisfied: packaging>=17.1 in c:\programdata\anaconda3\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jay\appdata\roaming\python\python312\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\programdata\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\jay\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp312-cp312-win_amd64.whl (625 kB)
#    ---------------------------------------- 0.0/625.1 kB ? eta -:--:--
#     --------------------------------------- 10.2/625.1 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/625.1 kB 653.6 kB/s eta 0:00:01
#    ------------------- -------------------- 307.2/625.1 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  624.6/625.1 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 625.1/625.1 kB 3.9 MB/s eta 0:00:00
# Downloading Cython-3.0.11-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.8 MB 10.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.8 MB 8.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.8 MB 6.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.8 MB 6.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.5/2.8 MB 6.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.2/2.8 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.11 pmdarima-2.0.4

# %%
model = auto_arima(df['Ex_rate_diff'] , m = 52, d = 1 ,seasonal = False , max_order = 8 , test = 'adf' , trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-55500.038, Time=2.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-49769.255, Time=1.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-52689.674, Time=1.70 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-55273.594, Time=1.72 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-49771.255, Time=0.48 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-55587.733, Time=3.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-55463.846, Time=3.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-54964.563, Time=1.82 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-55646.944, Time=3.54 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-55789.659, Time=3.19 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-55881.400, Time=3.73 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-55797.995, Time=5.76 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=12.51 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=-55882.283, Time=11.38 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=-55839.147, Time=10.89 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-55751.280, Time=5.01 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=-55866.556, Time=5.22 sec
#
# Best model:  ARIMA(1,1,5)(0,0,0)[0] intercept
# Total fit time: 77.264 seconds

# %% [markdown]
# ### Defining the summary of the model fitted with auto_arima function , here getting various information such as Akaike Information Criterion (AIC), Bayesian Information Criterion (BIC) , Hannan-Quinn Information Criterion (HQIC), Log Likelihood etc. From which we can evaluate the model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 7587
# Model:               SARIMAX(1, 1, 5)   Log Likelihood               27949.142
# Date:                Sun, 01 Dec 2024   AIC                         -55882.283
# Time:                        18:53:37   BIC                         -55826.811
# Sample:                             0   HQIC                        -55863.245
#                                - 7587
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -5.02e-06   6.07e-06     -0.828      0.408   -1.69e-05    6.87e-06
# ar.L1         -0.6959      0.002   -287.555      0.000      -0.701      -0.691
# ma.L1         -0.3808      0.003   -143.087      0.000      -0.386      -0.376
# ma.L2         -0.6249      0.004   -153.347      0.000      -0.633      -0.617
# ma.L3          0.0686      0.007     10.068      0.000       0.055       0.082
# ma.L4          0.0052      0.009      0.613      0.540      -0.011       0.022
# ma.L5          0.0130      0.008      1.569      0.117      -0.003       0.029
# sigma2      3.686e-05    1.1e-07    335.248      0.000    3.66e-05    3.71e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   6.32   Jarque-Bera (JB):           3024850.94
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.00   Skew:                             0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                       100.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.39e+16. Standard errors may be unstable.
# """

# %%
model = ARIMA(Ex_rate, order = (1,1,5))
result = model.fit()
result.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model = ARIMA(Ex_rate, order = (1,1,5))
#       2 result = model.fit()
#       3 result.summary()
#
# NameError: name 'ARIMA' is not defined

# %%
result.plot_diagnostics(figsize = (10,5))
plt.subplots_adjust(hspace = 0.5)
plt.savefig('Diagnostic plot of best model.png')
plt.show()

# %%
predictions = result.predict(typ = 'levels')
predictions
# Out:
# 0       0.000000
# 1       0.785500
# 2       0.782288
# 3       0.786053
# 4       0.786147
#           ...
# 7583    0.718797
# 7584    0.718541
# 7585    0.721402
# 7586    0.723031
# 7587    0.721058
# Name: predicted_mean, Length: 7588, dtype: float64

# %% [markdown]
# ### model evaluation

# %%
#Evaluating the model with the following metrics such as percentage of r2 score , mean squared error ,
# root mean squared error , mean absolute error and mean absolute percentage error for the predicted value and
 # whole data value.

# %%
#!pip install scikit-learn # Install the library first, if needed
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error,mean_absolute_percentage_error
from math import sqrt
df_week = pd.read_csv('exchange_rate.csv')
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
print('Evaluation Result for whole data : ','\n')
print('R2 Score for whole data : {0:.2f} %'.format(100*r2_score(df_week['Ex_rate'],predictions)),'\n')
print('Mean Squared Error : ',mean_squared_error(df_week['Ex_rate'],predictions),'\n')
print('Mean Absolute Error : ',mean_absolute_error(df_week['Ex_rate'],predictions),'\n')
print('Root Mean Squared Error : ',sqrt(mean_squared_error(df_week['Ex_rate'],predictions)),'\n')
print('Mean Absolute Percentage Error : {0:.2f} %'.format(100*mean_absolute_percentage_error(df_week['Ex_rate'],predictions)))
# Out:
# Evaluation Result for whole data :
#
# R2 Score for whole data : 99.37 %
#
# Mean Squared Error :  0.00011725977372101033
#
# Mean Absolute Error :  0.0037976237826361707
#
# Root Mean Squared Error :  0.010828655212952822
#
# Mean Absolute Percentage Error : 0.50 %

# %%
#Concating the Resampled weekly dataset and weekly first difference dataframe and the prediction value and
#naming the columns as Foreign Exchange Rate (weekly)','Weekly First Difference','Predicted Exchange Rate and
#exporting the dataframe to [Comma Seperated Value (CSV)] file.
#Also displaying the first five records of the exported dataframe.

# %%
# Importing the pandas library for data manipulation
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from math import sqrt

# Loading the exchange rate data
df_week = pd.read_csv('exchange_rate.csv')

# Assuming df1_week is meant to hold the weekly first difference, calculate it
# Replace 'Ex_rate' with the actual column name if different
df1_week = df_week['Ex_rate'].diff().fillna(0)  # Filling NaN with 0 for the first row

# ... rest of your code for model predictions ...

# Concating the dataframes
Final_data = pd.concat([df_week, df1_week, predictions], axis=1)
# Updated line to provide three column names matching the number of columns in Final_data
Final_data.columns = ['Date','Foreign Exchange Rate (weekly)', 'Weekly First Difference', 'Predicted Exchange Rate']
Final_data.to_csv('Foreign Exchange Rate with Prediction (USD to AUD).csv')
Final_data.head()
# Out:
#                Date  Foreign Exchange Rate (weekly)  Weekly First Difference  \
# 0  01-01-1990 00:00                          0.7855                   0.0000
# 1  02-01-1990 00:00                          0.7818                  -0.0037
# 2  03-01-1990 00:00                          0.7867                   0.0049
# 3  04-01-1990 00:00                          0.7860                  -0.0007
# 4  05-01-1990 00:00                          0.7849                  -0.0011
#
#    Predicted Exchange Rate
# 0                 0.000000
# 1                 0.785500
# 2                 0.782288
# 3                 0.786053
# 4                 0.786147

# %% [markdown]
# ### Model Testing
# Splliting the Resampled Weekly Dataset into training data and test data. Displaying the number of observations in both training data and test data.

# %%
size = int(len(df_week)*0.80)
train , test = df_week[0:size]['Ex_rate'] , df_week[size:(len(df_week))]['Ex_rate']
print('Counts of Train Data : ',train.shape[0])
print('Counts of Train Data : ',test.shape[0])
# Out:
# Counts of Train Data :  6070
# Counts of Train Data :  1518

# %% [markdown]
# ## expln
# Creating the list of train dataset values in train_values and empty predictions list which will be appended after the prediction. Then fitting the model with ARIMA model with the best value got from auto_arima model in the train_values data and predicting with test data value and appending it to the predictions list and printing the comparison between predicted value and actual value

# %%
size = int(len(df_week)*0.80)
train , test = df_week[0:size]['Ex_rate'] , df_week[size:(len(df_week))]['Ex_rate']
print('Counts of Train Data : ',train.shape[0])
print('Counts of Train Data : ',test.shape[0])

# Reset the index of the 'test' Series to start from 0
test = test.reset_index(drop=True)

train_values = [x for x in train]
prediction = []
print('Printing Predictied vs Expected Values....')
print('\n')
for t in range(len(test)):
    model = ARIMA(train_values , order = (0,1,1))
    model_fit = model.fit()
    output = model_fit.forecast()
    pred_out = output[0]
    prediction.append(float(pred_out))
    # Access 'test' using the reset index 't'
    test_in = test[t]
    train_values.append(test_in)
    print('Predicted = %f , Actual = %f' % (pred_out , test_in))
# Out:
# Counts of Train Data :  6070
# Counts of Train Data :  1518
# Printing Predictied vs Expected Values....
#
#
# Predicted = 1.023540 , Actual = 1.025347
# Predicted = 1.025243 , Actual = 1.026905
# Predicted = 1.026810 , Actual = 1.037344
# Predicted = 1.036740 , Actual = 1.038875
# Predicted = 1.038753 , Actual = 1.032855
# Predicted = 1.033193 , Actual = 1.033293
# Predicted = 1.033287 , Actual = 1.031800
# Predicted = 1.031885 , Actual = 1.025546
# Predicted = 1.025909 , Actual = 1.034650
# Predicted = 1.034148 , Actual = 1.035411
# Predicted = 1.035338 , Actual = 1.035025
# Predicted = 1.035043 , Actual = 1.033293
# Predicted = 1.033394 , Actual = 1.036549
# Predicted = 1.036368 , Actual = 1.037517
# Predicted = 1.037451 , Actual = 1.039933
# Predicted = 1.039790 , Actual = 1.036807
# Predicted = 1.036978 , Actual = 1.033592
# Predicted = 1.033786 , Actual = 1.036592
# Predicted = 1.036431 , Actual = 1.043841
# Predicted = 1.043416 , Actual = 1.040745
# Predicted = 1.040898 , Actual = 1.042731
# Predicted = 1.042626 , Actual = 1.039199
# Predicted = 1.039396 , Actual = 1.038551
# Predicted = 1.038600 , Actual = 1.042340
# Predicted = 1.042125 , Actual = 1.043406
# Predicted = 1.043332 , Actual = 1.039447
# Predicted = 1.039670 , Actual = 1.031342
# Predicted = 1.031820 , Actual = 1.030673
# Predicted = 1.030739 , Actual = 1.034351
# Predicted = 1.034144 , Actual = 1.040388
# Predicted = 1.040031 , Actual = 1.038044
# Predicted = 1.038158 , Actual = 1.034180
# Predicted = 1.034408 , Actual = 1.038206
# Predicted = 1.037988 , Actual = 1.044845
# Predicted = 1.044453 , Actual = 1.046249
# Predicted = 1.046146 , Actual = 1.044768
# Predicted = 1.044847 , Actual = 1.045686
# Predicted = 1.045638 , Actual = 1.046693
# Predicted = 1.046633 , Actual = 1.042601
# Predicted = 1.042832 , Actual = 1.042459
# Predicted = 1.042480 , Actual = 1.042802
# Predicted = 1.042784 , Actual = 1.043602
# Predicted = 1.043555 , Actual = 1.042872
# Predicted = 1.042911 , Actual = 1.047943
# Predicted = 1.047655 , Actual = 1.045467
# Predicted = 1.045592 , Actual = 1.049395
# Predicted = 1.049177 , Actual = 1.048652
# Predicted = 1.048682 , Actual = 1.048801
# Predicted = 1.048794 , Actual = 1.048801
# Predicted = 1.048801 , Actual = 1.049230
# Predicted = 1.049205 , Actual = 1.052028
# Predicted = 1.051866 , Actual = 1.053058
# Predicted = 1.052990 , Actual = 1.054847
# Predicted = 1.054741 , Actual = 1.056301
# Predicted = 1.056212 , Actual = 1.055749
# Predicted = 1.055775 , Actual = 1.054735
# Predicted = 1.054795 , Actual = 1.053025
# Predicted = 1.053126 , Actual = 1.049571
# Predicted = 1.049774 , Actual = 1.047663
# Predicted = 1.047784 , Actual = 1.041840
# Predicted = 1.042179 , Actual = 1.040350
# Predicted = 1.040454 , Actual = 1.036850
# Predicted = 1.037055 , Actual = 1.036602
# Predicted = 1.036628 , Actual = 1.034741
# Predicted = 1.034849 , Actual = 1.036044
# Predicted = 1.035976 , Actual = 1.038152
# Predicted = 1.038028 , Actual = 1.036801
# Predicted = 1.036871 , Actual = 1.038950
# Predicted = 1.038831 , Actual = 1.039501
# Predicted = 1.039463 , Actual = 1.049296
# Predicted = 1.048736 , Actual = 1.051431
# Predicted = 1.051278 , Actual = 1.045538
# Predicted = 1.045865 , Actual = 1.048196
# Predicted = 1.048063 , Actual = 1.048300
# Predicted = 1.048286 , Actual = 1.048141
# Predicted = 1.048149 , Actual = 1.048647
# Predicted = 1.048619 , Actual = 1.051668
# Predicted = 1.051494 , Actual = 1.057300
# Predicted = 1.056970 , Actual = 1.054241
# Predicted = 1.054396 , Actual = 1.053497
# Predicted = 1.053548 , Actual = 1.053497
# Predicted = 1.053500 , Actual = 1.056067
# Predicted = 1.055921 , Actual = 1.056200
# Predicted = 1.056184 , Actual = 1.056050
# Predicted = 1.056058 , Actual = 1.053769
# Predicted = 1.053899 , Actual = 1.049362
# Predicted = 1.049620 , Actual = 1.050801
# Predicted = 1.050734 , Actual = 1.050801
# Predicted = 1.050797 , Actual = 1.051353
# Predicted = 1.051321 , Actual = 1.055554
# Predicted = 1.055313 , Actual = 1.055147
# Predicted = 1.055156 , Actual = 1.046501
# Predicted = 1.046994 , Actual = 1.042063
# Predicted = 1.042343 , Actual = 1.042400
# Predicted = 1.042397 , Actual = 1.042150
# Predicted = 1.042164 , Actual = 1.040161
# Predicted = 1.040275 , Actual = 1.046507
# Predicted = 1.046153 , Actual = 1.042449
# Predicted = 1.042660 , Actual = 1.042731
# Predicted = 1.042727 , Actual = 1.041536
# Predicted = 1.041604 , Actual = 1.040101
# Predicted = 1.040186 , Actual = 1.040599
# Predicted = 1.040576 , Actual = 1.042503
# Predicted = 1.042393 , Actual = 1.038707
# Predicted = 1.038917 , Actual = 1.032002
# Predicted = 1.032395 , Actual = 1.028542
# Predicted = 1.028760 , Actual = 1.031662
# Predicted = 1.031497 , Actual = 1.031848
# Predicted = 1.031828 , Actual = 1.031848
# Predicted = 1.031847 , Actual = 1.028627
# Predicted = 1.028810 , Actual = 1.031050
# Predicted = 1.030923 , Actual = 1.034244
# Predicted = 1.034056 , Actual = 1.035084
# Predicted = 1.035026 , Actual = 1.030174
# Predicted = 1.030449 , Actual = 1.029999
# Predicted = 1.030025 , Actual = 1.029999
# Predicted = 1.030000 , Actual = 1.029601
# Predicted = 1.029624 , Actual = 1.035047
# Predicted = 1.034739 , Actual = 1.028373
# Predicted = 1.028735 , Actual = 1.025336
# Predicted = 1.025529 , Actual = 1.031151
# Predicted = 1.030831 , Actual = 1.032098
# Predicted = 1.032026 , Actual = 1.033053
# Predicted = 1.032995 , Actual = 1.028748
# Predicted = 1.028990 , Actual = 1.020544
# Predicted = 1.021023 , Actual = 1.020127
# Predicted = 1.020178 , Actual = 1.024102
# Predicted = 1.023880 , Actual = 1.020700
# Predicted = 1.020880 , Actual = 1.020700
# Predicted = 1.020710 , Actual = 1.016167
# Predicted = 1.016425 , Actual = 1.023667
# Predicted = 1.023255 , Actual = 1.025452
# Predicted = 1.025327 , Actual = 1.026352
# Predicted = 1.026294 , Actual = 1.022098
# Predicted = 1.022336 , Actual = 1.023400
# Predicted = 1.023340 , Actual = 1.023898
# Predicted = 1.023866 , Actual = 1.026267
# Predicted = 1.026131 , Actual = 1.031912
# Predicted = 1.031584 , Actual = 1.030641
# Predicted = 1.030695 , Actual = 1.039652
# Predicted = 1.039143 , Actual = 1.040399
# Predicted = 1.040328 , Actual = 1.040897
# Predicted = 1.040865 , Actual = 1.041303
# Predicted = 1.041278 , Actual = 1.039933
# Predicted = 1.040009 , Actual = 1.036549
# Predicted = 1.036745 , Actual = 1.039393
# Predicted = 1.039243 , Actual = 1.043776
# Predicted = 1.043519 , Actual = 1.044403
# Predicted = 1.044353 , Actual = 1.044299
# Predicted = 1.044302 , Actual = 1.044299
# Predicted = 1.044299 , Actual = 1.044998
# Predicted = 1.044958 , Actual = 1.047554
# Predicted = 1.047407 , Actual = 1.043830
# Predicted = 1.044033 , Actual = 1.041271
# Predicted = 1.041428 , Actual = 1.040940
# Predicted = 1.040968 , Actual = 1.041499
# Predicted = 1.041469 , Actual = 1.041499
# Predicted = 1.041497 , Actual = 1.042949
# Predicted = 1.042867 , Actual = 1.045402
# Predicted = 1.045258 , Actual = 1.047861
# Predicted = 1.047714 , Actual = 1.040031
# Predicted = 1.040467 , Actual = 1.038346
# Predicted = 1.038466 , Actual = 1.042753
# Predicted = 1.042510 , Actual = 1.037597
# Predicted = 1.037876 , Actual = 1.039679
# Predicted = 1.039576 , Actual = 1.049164
# Predicted = 1.048619 , Actual = 1.053707
# Predicted = 1.053419 , Actual = 1.054902
# Predicted = 1.054818 , Actual = 1.050547
# Predicted = 1.050789 , Actual = 1.050001
# Predicted = 1.050046 , Actual = 1.050900
# Predicted = 1.050852 , Actual = 1.037646
# Predicted = 1.038393 , Actual = 1.039301
# Predicted = 1.039250 , Actual = 1.029898
# Predicted = 1.030428 , Actual = 1.030137
# Predicted = 1.030153 , Actual = 1.029484
# Predicted = 1.029522 , Actual = 1.029400
# Predicted = 1.029407 , Actual = 1.027802
# Predicted = 1.027893 , Actual = 1.025546
# Predicted = 1.025679 , Actual = 1.025452
# Predicted = 1.025465 , Actual = 1.026388
# Predicted = 1.026336 , Actual = 1.031300
# Predicted = 1.031019 , Actual = 1.028468
# Predicted = 1.028613 , Actual = 1.028050
# Predicted = 1.028082 , Actual = 1.028050
# Predicted = 1.028052 , Actual = 1.035299
# Predicted = 1.034888 , Actual = 1.036001
# Predicted = 1.035938 , Actual = 1.028849
# Predicted = 1.029251 , Actual = 1.025925
# Predicted = 1.026113 , Actual = 1.031199
# Predicted = 1.030911 , Actual = 1.032002
# Predicted = 1.031940 , Actual = 1.026252
# Predicted = 1.026574 , Actual = 1.024711
# Predicted = 1.024816 , Actual = 1.017750
# Predicted = 1.018150 , Actual = 1.018180
# Predicted = 1.018178 , Actual = 1.017636
# Predicted = 1.017667 , Actual = 1.002195
# Predicted = 1.003069 , Actual = 1.001101
# Predicted = 1.001212 , Actual = 1.001101
# Predicted = 1.001107 , Actual = 0.994382
# Predicted = 0.994761 , Actual = 0.989462
# Predicted = 0.989760 , Actual = 0.987752
# Predicted = 0.987865 , Actual = 0.984300
# Predicted = 0.984500 , Actual = 0.974042
# Predicted = 0.974627 , Actual = 0.972810
# Predicted = 0.972911 , Actual = 0.972810
# Predicted = 0.972816 , Actual = 0.981306
# Predicted = 0.980832 , Actual = 0.981884
# Predicted = 0.981825 , Actual = 0.969415
# Predicted = 0.970108 , Actual = 0.974469
# Predicted = 0.974224 , Actual = 0.964041
# Predicted = 0.964615 , Actual = 0.964785
# Predicted = 0.964775 , Actual = 0.967492
# Predicted = 0.967339 , Actual = 0.963066
# Predicted = 0.963307 , Actual = 0.963577
# Predicted = 0.963562 , Actual = 0.962881
# Predicted = 0.962919 , Actual = 0.966978
# Predicted = 0.966749 , Actual = 0.959739
# Predicted = 0.960135 , Actual = 0.978809
# Predicted = 0.977741 , Actual = 0.961862
# Predicted = 0.962791 , Actual = 0.953334
# Predicted = 0.953881 , Actual = 0.959923
# Predicted = 0.959572 , Actual = 0.948092
# Predicted = 0.948764 , Actual = 0.949487
# Predicted = 0.949445 , Actual = 0.950029
# Predicted = 0.949995 , Actual = 0.946647
# Predicted = 0.946843 , Actual = 0.941886
# Predicted = 0.942176 , Actual = 0.950074
# Predicted = 0.949610 , Actual = 0.960108
# Predicted = 0.959496 , Actual = 0.958819
# Predicted = 0.958858 , Actual = 0.956892
# Predicted = 0.957007 , Actual = 0.956892
# Predicted = 0.956899 , Actual = 0.953971
# Predicted = 0.954142 , Actual = 0.949532
# Predicted = 0.949801 , Actual = 0.953880
# Predicted = 0.953642 , Actual = 0.919794
# Predicted = 0.921792 , Actual = 0.922765
# Predicted = 0.922708 , Actual = 0.926698
# Predicted = 0.926462 , Actual = 0.926655
# Predicted = 0.926644 , Actual = 0.926741
# Predicted = 0.926735 , Actual = 0.928031
# Predicted = 0.927954 , Actual = 0.913826
# Predicted = 0.914663 , Actual = 0.913993
# Predicted = 0.914033 , Actual = 0.914244
# Predicted = 0.914231 , Actual = 0.923404
# Predicted = 0.922861 , Actual = 0.914119
# Predicted = 0.914640 , Actual = 0.907153
# Predicted = 0.907597 , Actual = 0.915961
# Predicted = 0.915463 , Actual = 0.905510
# Predicted = 0.906107 , Actual = 0.906906
# Predicted = 0.906858 , Actual = 0.906906
# Predicted = 0.906903 , Actual = 0.912492
# Predicted = 0.912157 , Actual = 0.917473
# Predicted = 0.917155 , Actual = 0.914955
# Predicted = 0.915087 , Actual = 0.913784
# Predicted = 0.913862 , Actual = 0.905100
# Predicted = 0.905625 , Actual = 0.904895
# Predicted = 0.904939 , Actual = 0.904895
# Predicted = 0.904898 , Actual = 0.908884
# Predicted = 0.908645 , Actual = 0.923788
# Predicted = 0.922886 , Actual = 0.923233
# Predicted = 0.923212 , Actual = 0.916842
# Predicted = 0.917221 , Actual = 0.919413
# Predicted = 0.919282 , Actual = 0.917389
# Predicted = 0.917502 , Actual = 0.918991
# Predicted = 0.918902 , Actual = 0.925455
# Predicted = 0.925064 , Actual = 0.928591
# Predicted = 0.928381 , Actual = 0.914913
# Predicted = 0.915717 , Actual = 0.922637
# Predicted = 0.922221 , Actual = 0.925369
# Predicted = 0.925180 , Actual = 0.926312
# Predicted = 0.926244 , Actual = 0.926312
# Predicted = 0.926308 , Actual = 0.919118
# Predicted = 0.919550 , Actual = 0.905518
# Predicted = 0.906354 , Actual = 0.896580
# Predicted = 0.897155 , Actual = 0.893895
# Predicted = 0.894086 , Actual = 0.891504
# Predicted = 0.891656 , Actual = 0.890591
# Predicted = 0.890654 , Actual = 0.890591
# Predicted = 0.890595 , Actual = 0.890948
# Predicted = 0.890927 , Actual = 0.898957
# Predicted = 0.898486 , Actual = 0.900293
# Predicted = 0.900187 , Actual = 0.911785
# Predicted = 0.911106 , Actual = 0.919667
# Predicted = 0.919170 , Actual = 0.919033
# Predicted = 0.919041 , Actual = 0.919033
# Predicted = 0.919033 , Actual = 0.915290
# Predicted = 0.915507 , Actual = 0.909298
# Predicted = 0.909658 , Actual = 0.913200
# Predicted = 0.912994 , Actual = 0.913034
# Predicted = 0.913032 , Actual = 0.917557
# Predicted = 0.917294 , Actual = 0.918358
# Predicted = 0.918296 , Actual = 0.918358
# Predicted = 0.918354 , Actual = 0.912284
# Predicted = 0.912636 , Actual = 0.908637
# Predicted = 0.908869 , Actual = 0.903261
# Predicted = 0.903585 , Actual = 0.902772
# Predicted = 0.902819 , Actual = 0.903138
# Predicted = 0.903120 , Actual = 0.902731
# Predicted = 0.902753 , Actual = 0.903424
# Predicted = 0.903385 , Actual = 0.902161
# Predicted = 0.902232 , Actual = 0.896740
# Predicted = 0.897057 , Actual = 0.894374
# Predicted = 0.894529 , Actual = 0.892977
# Predicted = 0.893066 , Actual = 0.890234
# Predicted = 0.890397 , Actual = 0.890076
# Predicted = 0.890095 , Actual = 0.890036
# Predicted = 0.890039 , Actual = 0.897787
# Predicted = 0.897340 , Actual = 0.904773
# Predicted = 0.904347 , Actual = 0.916800
# Predicted = 0.916091 , Actual = 0.911993
# Predicted = 0.912227 , Actual = 0.919498
# Predicted = 0.919081 , Actual = 0.918949
# Predicted = 0.918957 , Actual = 0.918949
# Predicted = 0.918949 , Actual = 0.923702
# Predicted = 0.923430 , Actual = 0.930795
# Predicted = 0.930374 , Actual = 0.933140
# Predicted = 0.932982 , Actual = 0.926398
# Predicted = 0.926774 , Actual = 0.924813
# Predicted = 0.924925 , Actual = 0.924599
# Predicted = 0.924618 , Actual = 0.924599
# Predicted = 0.924600 , Actual = 0.932140
# Predicted = 0.931710 , Actual = 0.935454
# Predicted = 0.935241 , Actual = 0.937207
# Predicted = 0.937095 , Actual = 0.943352
# Predicted = 0.942996 , Actual = 0.941531
# Predicted = 0.941614 , Actual = 0.939408
# Predicted = 0.939533 , Actual = 0.939408
# Predicted = 0.939415 , Actual = 0.944153
# Predicted = 0.943884 , Actual = 0.940513
# Predicted = 0.940705 , Actual = 0.936505
# Predicted = 0.936744 , Actual = 0.934536
# Predicted = 0.934661 , Actual = 0.932184
# Predicted = 0.932325 , Actual = 0.931489
# Predicted = 0.931536 , Actual = 0.931793
# Predicted = 0.931778 , Actual = 0.933489
# Predicted = 0.933392 , Actual = 0.939276
# Predicted = 0.938942 , Actual = 0.937075
# Predicted = 0.937181 , Actual = 0.940513
# Predicted = 0.940324 , Actual = 0.943174
# Predicted = 0.943012 , Actual = 0.943085
# Predicted = 0.943081 , Actual = 0.943352
# Predicted = 0.943337 , Actual = 0.943886
# Predicted = 0.943855 , Actual = 0.943174
# Predicted = 0.943213 , Actual = 0.942818
# Predicted = 0.942840 , Actual = 0.946387
# Predicted = 0.946186 , Actual = 0.946925
# Predicted = 0.946883 , Actual = 0.946701
# Predicted = 0.946711 , Actual = 0.946701
# Predicted = 0.946702 , Actual = 0.947912
# Predicted = 0.947843 , Actual = 0.952336
# Predicted = 0.952081 , Actual = 0.953652
# Predicted = 0.953563 , Actual = 0.963948
# Predicted = 0.963360 , Actual = 0.967024
# Predicted = 0.966817 , Actual = 0.967212
# Predicted = 0.967190 , Actual = 0.967586
# Predicted = 0.967564 , Actual = 0.965997
# Predicted = 0.966085 , Actual = 0.970591
# Predicted = 0.970336 , Actual = 0.961908
# Predicted = 0.962386 , Actual = 0.960984
# Predicted = 0.961063 , Actual = 0.957717
# Predicted = 0.957906 , Actual = 0.958589
# Predicted = 0.958550 , Actual = 0.958543
# Predicted = 0.958543 , Actual = 0.957579
# Predicted = 0.957634 , Actual = 0.948452
# Predicted = 0.948971 , Actual = 0.949487
# Predicted = 0.949458 , Actual = 0.945716
# Predicted = 0.945928 , Actual = 0.944020
# Predicted = 0.944128 , Actual = 0.943797
# Predicted = 0.943816 , Actual = 0.943129
# Predicted = 0.943168 , Actual = 0.950796
# Predicted = 0.950364 , Actual = 0.948902
# Predicted = 0.948985 , Actual = 0.951973
# Predicted = 0.951804 , Actual = 0.946970
# Predicted = 0.947244 , Actual = 0.938218
# Predicted = 0.938728 , Actual = 0.938130
# Predicted = 0.938164 , Actual = 0.938130
# Predicted = 0.938132 , Actual = 0.935366
# Predicted = 0.935522 , Actual = 0.929930
# Predicted = 0.930245 , Actual = 0.932618
# Predicted = 0.932484 , Actual = 0.932053
# Predicted = 0.932077 , Actual = 0.936154
# Predicted = 0.935924 , Actual = 0.937251
# Predicted = 0.937176 , Actual = 0.936988
# Predicted = 0.936999 , Actual = 0.939761
# Predicted = 0.939605 , Actual = 0.941309
# Predicted = 0.941213 , Actual = 0.937119
# Predicted = 0.937350 , Actual = 0.924727
# Predicted = 0.925437 , Actual = 0.916170
# Predicted = 0.916686 , Actual = 0.917389
# Predicted = 0.917350 , Actual = 0.914997
# Predicted = 0.915128 , Actual = 0.914746
# Predicted = 0.914767 , Actual = 0.912201
# Predicted = 0.912344 , Actual = 0.907606
# Predicted = 0.907870 , Actual = 0.909215
# Predicted = 0.909140 , Actual = 0.912284
# Predicted = 0.912109 , Actual = 0.911079
# Predicted = 0.911136 , Actual = 0.911079
# Predicted = 0.911082 , Actual = 0.910208
# Predicted = 0.910257 , Actual = 0.912409
# Predicted = 0.912289 , Actual = 0.901307
# Predicted = 0.901920 , Actual = 0.907112
# Predicted = 0.906821 , Actual = 0.909711
# Predicted = 0.909549 , Actual = 0.910208
# Predicted = 0.910171 , Actual = 0.910208
# Predicted = 0.910206 , Actual = 0.908529
# Predicted = 0.908623 , Actual = 0.915290
# Predicted = 0.914916 , Actual = 0.906495
# Predicted = 0.906969 , Actual = 0.892538
# Predicted = 0.893342 , Actual = 0.895817
# Predicted = 0.895679 , Actual = 0.896338
# Predicted = 0.896301 , Actual = 0.896338
# Predicted = 0.896336 , Actual = 0.896700
# Predicted = 0.896680 , Actual = 0.889996
# Predicted = 0.890370 , Actual = 0.888178
# Predicted = 0.888300 , Actual = 0.886171
# Predicted = 0.886290 , Actual = 0.891981
# Predicted = 0.891663 , Actual = 0.892618
# Predicted = 0.892565 , Actual = 0.892618
# Predicted = 0.892615 , Actual = 0.893695
# Predicted = 0.893635 , Actual = 0.892100
# Predicted = 0.892186 , Actual = 0.892299
# Predicted = 0.892293 , Actual = 0.888455
# Predicted = 0.888669 , Actual = 0.888455
# Predicted = 0.888467 , Actual = 0.886525
# Predicted = 0.886633 , Actual = 0.886525
# Predicted = 0.886531 , Actual = 0.891941
# Predicted = 0.891639 , Actual = 0.893136
# Predicted = 0.893052 , Actual = 0.891305
# Predicted = 0.891403 , Actual = 0.892339
# Predicted = 0.892287 , Actual = 0.897787
# Predicted = 0.897480 , Actual = 0.893855
# Predicted = 0.894058 , Actual = 0.893855
# Predicted = 0.893866 , Actual = 0.895456
# Predicted = 0.895367 , Actual = 0.891981
# Predicted = 0.892170 , Actual = 0.890908
# Predicted = 0.890979 , Actual = 0.888573
# Predicted = 0.888707 , Actual = 0.898029
# Predicted = 0.897507 , Actual = 0.891782
# Predicted = 0.892104 , Actual = 0.899726
# Predicted = 0.899296 , Actual = 0.905100
# Predicted = 0.904774 , Actual = 0.897666
# Predicted = 0.898067 , Actual = 0.892459
# Predicted = 0.892775 , Actual = 0.880165
# Predicted = 0.880870 , Actual = 0.878156
# Predicted = 0.878307 , Actual = 0.878310
# Predicted = 0.878310 , Actual = 0.878310
# Predicted = 0.878310 , Actual = 0.879933
# Predicted = 0.879842 , Actual = 0.880398
# Predicted = 0.880367 , Actual = 0.884408
# Predicted = 0.884183 , Actual = 0.877193
# Predicted = 0.877584 , Actual = 0.871004
# Predicted = 0.871370 , Actual = 0.868395
# Predicted = 0.868560 , Actual = 0.871080
# Predicted = 0.870940 , Actual = 0.873439
# Predicted = 0.873300 , Actual = 0.876808
# Predicted = 0.876613 , Actual = 0.876255
# Predicted = 0.876275 , Actual = 0.876924
# Predicted = 0.876888 , Actual = 0.873477
# Predicted = 0.873666 , Actual = 0.875503
# Predicted = 0.875401 , Actual = 0.875120
# Predicted = 0.875136 , Actual = 0.877925
# Predicted = 0.877770 , Actual = 0.893336
# Predicted = 0.892474 , Actual = 0.891107
# Predicted = 0.891183 , Actual = 0.896620
# Predicted = 0.896318 , Actual = 0.895817
# Predicted = 0.895845 , Actual = 0.895696
# Predicted = 0.895704 , Actual = 0.895696
# Predicted = 0.895696 , Actual = 0.894174
# Predicted = 0.894259 , Actual = 0.904364
# Predicted = 0.903802 , Actual = 0.902812
# Predicted = 0.902867 , Actual = 0.897747
# Predicted = 0.898032 , Actual = 0.902120
# Predicted = 0.901892 , Actual = 0.903669
# Predicted = 0.903570 , Actual = 0.903669
# Predicted = 0.903663 , Actual = 0.903204
# Predicted = 0.903230 , Actual = 0.903710
# Predicted = 0.903683 , Actual = 0.903138
# Predicted = 0.903168 , Actual = 0.898311
# Predicted = 0.898582 , Actual = 0.895937
# Predicted = 0.896084 , Actual = 0.897706
# Predicted = 0.897616 , Actual = 0.897706
# Predicted = 0.897701 , Actual = 0.904037
# Predicted = 0.903684 , Actual = 0.902649
# Predicted = 0.902707 , Actual = 0.895736
# Predicted = 0.896124 , Actual = 0.895696
# Predicted = 0.895720 , Actual = 0.893695
# Predicted = 0.893808 , Actual = 0.892897
# Predicted = 0.892948 , Actual = 0.892897
# Predicted = 0.892900 , Actual = 0.892698
# Predicted = 0.892709 , Actual = 0.893815
# Predicted = 0.893753 , Actual = 0.898190
# Predicted = 0.897943 , Actual = 0.909298
# Predicted = 0.908669 , Actual = 0.907359
# Predicted = 0.907432 , Actual = 0.906988
# Predicted = 0.907013 , Actual = 0.906906
# Predicted = 0.906912 , Actual = 0.902079
# Predicted = 0.902347 , Actual = 0.900584
# Predicted = 0.900682 , Actual = 0.897908
# Predicted = 0.898062 , Actual = 0.904691
# Predicted = 0.904323 , Actual = 0.903506
# Predicted = 0.903551 , Actual = 0.903098
# Predicted = 0.903123 , Actual = 0.903098
# Predicted = 0.903099 , Actual = 0.909132
# Predicted = 0.908797 , Actual = 0.913159
# Predicted = 0.912918 , Actual = 0.911868
# Predicted = 0.911926 , Actual = 0.904773
# Predicted = 0.905169 , Actual = 0.909174
# Predicted = 0.908952 , Actual = 0.908306
# Predicted = 0.908342 , Actual = 0.908306
# Predicted = 0.908308 , Actual = 0.911785
# Predicted = 0.911592 , Actual = 0.915039
# Predicted = 0.914848 , Actual = 0.922382
# Predicted = 0.921965 , Actual = 0.925412
# Predicted = 0.925222 , Actual = 0.924129
# Predicted = 0.924189 , Actual = 0.924684
# Predicted = 0.924657 , Actual = 0.924684
# Predicted = 0.924682 , Actual = 0.926870
# Predicted = 0.926749 , Actual = 0.924684
# Predicted = 0.924798 , Actual = 0.923916
# Predicted = 0.923965 , Actual = 0.922084
# Predicted = 0.922188 , Actual = 0.928505
# Predicted = 0.928156 , Actual = 0.928376
# Predicted = 0.928364 , Actual = 0.929411
# Predicted = 0.929353 , Actual = 0.926055
# Predicted = 0.926237 , Actual = 0.935804
# Predicted = 0.935274 , Actual = 0.934973
# Predicted = 0.934990 , Actual = 0.942196
# Predicted = 0.941797 , Actual = 0.939673
# Predicted = 0.939791 , Actual = 0.939452
# Predicted = 0.939471 , Actual = 0.939496
# Predicted = 0.939495 , Actual = 0.941531
# Predicted = 0.941418 , Actual = 0.934885
# Predicted = 0.935248 , Actual = 0.937734
# Predicted = 0.937596 , Actual = 0.933358
# Predicted = 0.933594 , Actual = 0.933315
# Predicted = 0.933331 , Actual = 0.932749
# Predicted = 0.932781 , Actual = 0.932879
# Predicted = 0.932874 , Actual = 0.933576
# Predicted = 0.933537 , Actual = 0.936549
# Predicted = 0.936381 , Actual = 0.928290
# Predicted = 0.928741 , Actual = 0.925583
# Predicted = 0.925759 , Actual = 0.926784
# Predicted = 0.926727 , Actual = 0.926870
# Predicted = 0.926862 , Actual = 0.926870
# Predicted = 0.926870 , Actual = 0.924813
# Predicted = 0.924927 , Actual = 0.926999
# Predicted = 0.926884 , Actual = 0.927601
# Predicted = 0.927561 , Actual = 0.927429
# Predicted = 0.927436 , Actual = 0.926398
# Predicted = 0.926456 , Actual = 1.077760
# Predicted = 1.069224 , Actual = 0.927687
# Predicted = 0.946223 , Actual = 0.927558
# Predicted = 0.929964 , Actual = 0.936373
# Predicted = 0.935502 , Actual = 0.934230
# Predicted = 0.934403 , Actual = 0.938571
# Predicted = 0.938002 , Actual = 0.935673
# Predicted = 0.935991 , Actual = 0.936505
# Predicted = 0.936435 , Actual = 0.936505
# Predicted = 0.936495 , Actual = 0.936461
# Predicted = 0.936466 , Actual = 0.934929
# Predicted = 0.935139 , Actual = 0.938130
# Predicted = 0.937722 , Actual = 0.934667
# Predicted = 0.935084 , Actual = 0.936593
# Predicted = 0.936387 , Actual = 0.936330
# Predicted = 0.936338 , Actual = 0.936330
# Predicted = 0.936331 , Actual = 0.933532
# Predicted = 0.933914 , Actual = 0.924684
# Predicted = 0.925943 , Actual = 0.921999
# Predicted = 0.922536 , Actual = 0.921829
# Predicted = 0.921925 , Actual = 0.923745
# Predicted = 0.923497 , Actual = 0.923105
# Predicted = 0.923158 , Actual = 0.923063
# Predicted = 0.923076 , Actual = 0.924172
# Predicted = 0.924023 , Actual = 0.923660
# Predicted = 0.923709 , Actual = 0.922424
# Predicted = 0.922599 , Actual = 0.928764
# Predicted = 0.927924 , Actual = 0.930536
# Predicted = 0.930180 , Actual = 0.930622
# Predicted = 0.930562 , Actual = 0.930622
# Predicted = 0.930614 , Actual = 0.924513
# Predicted = 0.925344 , Actual = 0.925369
# Predicted = 0.925366 , Actual = 0.927171
# Predicted = 0.926925 , Actual = 0.933010
# Predicted = 0.932181 , Actual = 0.933489
# Predicted = 0.933311 , Actual = 0.933228
# Predicted = 0.933239 , Actual = 0.933228
# Predicted = 0.933230 , Actual = 0.934973
# Predicted = 0.934736 , Actual = 0.936417
# Predicted = 0.936188 , Actual = 0.938482
# Predicted = 0.938170 , Actual = 0.942196
# Predicted = 0.941648 , Actual = 0.939717
# Predicted = 0.939980 , Actual = 0.940291
# Predicted = 0.940249 , Actual = 0.940291
# Predicted = 0.940285 , Actual = 0.939496
# Predicted = 0.939603 , Actual = 0.933445
# Predicted = 0.934283 , Actual = 0.934099
# Predicted = 0.934124 , Actual = 0.939364
# Predicted = 0.938651 , Actual = 0.938747
# Predicted = 0.938734 , Actual = 0.938923
# Predicted = 0.938897 , Actual = 0.938659
# Predicted = 0.938691 , Actual = 0.941841
# Predicted = 0.941412 , Actual = 0.937866
# Predicted = 0.938349 , Actual = 0.939055
# Predicted = 0.938959 , Actual = 0.940690
# Predicted = 0.940454 , Actual = 0.941487
# Predicted = 0.941346 , Actual = 0.942374
# Predicted = 0.942234 , Actual = 0.942374
# Predicted = 0.942355 , Actual = 0.942640
# Predicted = 0.942601 , Actual = 0.950029
# Predicted = 0.949018 , Actual = 0.943797
# Predicted = 0.944508 , Actual = 0.935148
# Predicted = 0.936422 , Actual = 0.936417
# Predicted = 0.936418 , Actual = 0.936724
# Predicted = 0.936682 , Actual = 0.936330
# Predicted = 0.936378 , Actual = 0.937163
# Predicted = 0.937056 , Actual = 0.940203
# Predicted = 0.939775 , Actual = 0.939408
# Predicted = 0.939458 , Actual = 0.939320
# Predicted = 0.939339 , Actual = 0.938262
# Predicted = 0.938409 , Actual = 0.939099
# Predicted = 0.939005 , Actual = 0.939099
# Predicted = 0.939086 , Actual = 0.938879
# Predicted = 0.938907 , Actual = 0.936680
# Predicted = 0.936983 , Actual = 0.936461
# Predicted = 0.936532 , Actual = 0.938130
# Predicted = 0.937912 , Actual = 0.939629
# Predicted = 0.939395 , Actual = 0.939276
# Predicted = 0.939292 , Actual = 0.939320
# Predicted = 0.939316 , Actual = 0.937603
# Predicted = 0.937836 , Actual = 0.939320
# Predicted = 0.939118 , Actual = 0.945001
# Predicted = 0.944200 , Actual = 0.941487
# Predicted = 0.941856 , Actual = 0.940115
# Predicted = 0.940352 , Actual = 0.939541
# Predicted = 0.939651 , Actual = 0.939585
# Predicted = 0.939594 , Actual = 0.940999
# Predicted = 0.940808 , Actual = 0.938659
# Predicted = 0.938952 , Actual = 0.931966
# Predicted = 0.932917 , Actual = 0.930362
# Predicted = 0.930709 , Actual = 0.931272
# Predicted = 0.931195 , Actual = 0.931142
# Predicted = 0.931149 , Actual = 0.931142
# Predicted = 0.931143 , Actual = 0.933097
# Predicted = 0.932831 , Actual = 0.929627
# Predicted = 0.930063 , Actual = 0.934885
# Predicted = 0.934229 , Actual = 0.927515
# Predicted = 0.928430 , Actual = 0.927687
# Predicted = 0.927788 , Actual = 0.927773
# Predicted = 0.927775 , Actual = 0.927773
# Predicted = 0.927773 , Actual = 0.926012
# Predicted = 0.926252 , Actual = 0.927171
# Predicted = 0.927046 , Actual = 0.930665
# Predicted = 0.930172 , Actual = 0.931402
# Predicted = 0.931235 , Actual = 0.931402
# Predicted = 0.931379 , Actual = 0.932401
# Predicted = 0.932262 , Actual = 0.932401
# Predicted = 0.932382 , Actual = 0.932705
# Predicted = 0.932661 , Actual = 0.930665
# Predicted = 0.930937 , Actual = 0.931099
# Predicted = 0.931077 , Actual = 0.930319
# Predicted = 0.930422 , Actual = 0.931446
# Predicted = 0.931307 , Actual = 0.931055
# Predicted = 0.931089 , Actual = 0.929843
# Predicted = 0.930013 , Actual = 0.930579
# Predicted = 0.930502 , Actual = 0.933707
# Predicted = 0.933271 , Actual = 0.935235
# Predicted = 0.934968 , Actual = 0.933707
# Predicted = 0.933879 , Actual = 0.933968
# Predicted = 0.933956 , Actual = 0.933968
# Predicted = 0.933966 , Actual = 0.933750
# Predicted = 0.933779 , Actual = 0.927730
# Predicted = 0.928554 , Actual = 0.934187
# Predicted = 0.933419 , Actual = 0.935629
# Predicted = 0.935328 , Actual = 0.937647
# Predicted = 0.937331 , Actual = 0.937822
# Predicted = 0.937755 , Actual = 0.929023
# Predicted = 0.930213 , Actual = 0.919794
# Predicted = 0.921209 , Actual = 0.915919
# Predicted = 0.916636 , Actual = 0.910871
# Predicted = 0.911652 , Actual = 0.904640
# Predicted = 0.905589 , Actual = 0.904640
# Predicted = 0.904768 , Actual = 0.902660
# Predicted = 0.902945 , Actual = 0.908720
# Predicted = 0.907938 , Actual = 0.908720
# Predicted = 0.908614 , Actual = 0.903383
# Predicted = 0.904091 , Actual = 0.897714
# Predicted = 0.898577 , Actual = 0.893495
# Predicted = 0.894182 , Actual = 0.892897
# Predicted = 0.893071 , Actual = 0.892897
# Predicted = 0.892920 , Actual = 0.886682
# Predicted = 0.887525 , Actual = 0.883923
# Predicted = 0.884409 , Actual = 0.879391
# Predicted = 0.880068 , Actual = 0.876271
# Predicted = 0.876783 , Actual = 0.876578
# Predicted = 0.876606 , Actual = 0.876578
# Predicted = 0.876582 , Actual = 0.873057
# Predicted = 0.873532 , Actual = 0.873897
# Predicted = 0.873848 , Actual = 0.872106
# Predicted = 0.872341 , Actual = 0.867420
# Predicted = 0.868084 , Actual = 0.867420
# Predicted = 0.867509 , Actual = 0.867420
# Predicted = 0.867432 , Actual = 0.873820
# Predicted = 0.872959 , Actual = 0.881180
# Predicted = 0.880073 , Actual = 0.881180
# Predicted = 0.881031 , Actual = 0.875312
# Predicted = 0.876082 , Actual = 0.877770
# Predicted = 0.877543 , Actual = 0.872791
# Predicted = 0.873431 , Actual = 0.868508
# Predicted = 0.869171 , Actual = 0.868508
# Predicted = 0.868597 , Actual = 0.875580
# Predicted = 0.874640 , Actual = 0.873019
# Predicted = 0.873237 , Actual = 0.879856
# Predicted = 0.878964 , Actual = 0.876962
# Predicted = 0.877232 , Actual = 0.877078
# Predicted = 0.877099 , Actual = 0.874508
# Predicted = 0.874857 , Actual = 0.874508
# Predicted = 0.874555 , Actual = 0.878735
# Predicted = 0.878172 , Actual = 0.879585
# Predicted = 0.879395 , Actual = 0.878503
# Predicted = 0.878623 , Actual = 0.876194
# Predicted = 0.876521 , Actual = 0.880669
# Predicted = 0.880110 , Actual = 0.879314
# Predicted = 0.879421 , Actual = 0.879314
# Predicted = 0.879328 , Actual = 0.881096
# Predicted = 0.880858 , Actual = 0.885112
# Predicted = 0.884539 , Actual = 0.889324
# Predicted = 0.888680 , Actual = 0.883041
# Predicted = 0.883801 , Actual = 0.880049
# Predicted = 0.880554 , Actual = 0.879624
# Predicted = 0.879749 , Actual = 0.879624
# Predicted = 0.879641 , Actual = 0.869792
# Predicted = 0.871118 , Actual = 0.872753
# Predicted = 0.872533 , Actual = 0.858959
# Predicted = 0.860789 , Actual = 0.858369
# Predicted = 0.858695 , Actual = 0.861958
# Predicted = 0.861518 , Actual = 0.863297
# Predicted = 0.863057 , Actual = 0.863297
# Predicted = 0.863265 , Actual = 0.862627
# Predicted = 0.862713 , Actual = 0.867303
# Predicted = 0.866685 , Actual = 0.873782
# Predicted = 0.872827 , Actual = 0.872638
# Predicted = 0.872663 , Actual = 0.873477
# Predicted = 0.873367 , Actual = 0.874508
# Predicted = 0.874354 , Actual = 0.875848
# Predicted = 0.875647 , Actual = 0.871802
# Predicted = 0.872320 , Actual = 0.872486
# Predicted = 0.872464 , Actual = 0.862738
# Predicted = 0.864047 , Actual = 0.860696
# Predicted = 0.861147 , Actual = 0.867303
# Predicted = 0.866475 , Actual = 0.867002
# Predicted = 0.866931 , Actual = 0.867002
# Predicted = 0.866992 , Actual = 0.861920
# Predicted = 0.862603 , Actual = 0.852406
# Predicted = 0.853776 , Actual = 0.853424
# Predicted = 0.853471 , Actual = 0.854555
# Predicted = 0.854409 , Actual = 0.852479
# Predicted = 0.852738 , Actual = 0.850738
# Predicted = 0.851007 , Actual = 0.850738
# Predicted = 0.850774 , Actual = 0.851499
# Predicted = 0.851402 , Actual = 0.845201
# Predicted = 0.846034 , Actual = 0.841857
# Predicted = 0.842418 , Actual = 0.840795
# Predicted = 0.841013 , Actual = 0.832882
# Predicted = 0.833973 , Actual = 0.832605
# Predicted = 0.832788 , Actual = 0.832605
# Predicted = 0.832630 , Actual = 0.829841
# Predicted = 0.830215 , Actual = 0.833507
# Predicted = 0.833065 , Actual = 0.830358
# Predicted = 0.830721 , Actual = 0.826788
# Predicted = 0.827316 , Actual = 0.826105
# Predicted = 0.826267 , Actual = 0.824198
# Predicted = 0.824476 , Actual = 0.824198
# Predicted = 0.824235 , Actual = 0.822301
# Predicted = 0.822560 , Actual = 0.822064
# Predicted = 0.822131 , Actual = 0.816627
# Predicted = 0.817365 , Actual = 0.816593
# Predicted = 0.816697 , Actual = 0.812909
# Predicted = 0.813417 , Actual = 0.814332
# Predicted = 0.814209 , Actual = 0.814332
# Predicted = 0.814316 , Actual = 0.814166
# Predicted = 0.814186 , Actual = 0.809540
# Predicted = 0.810163 , Actual = 0.810964
# Predicted = 0.810857 , Actual = 0.811129
# Predicted = 0.811092 , Actual = 0.811326
# Predicted = 0.811295 , Actual = 0.810750
# Predicted = 0.810823 , Actual = 0.810750
# Predicted = 0.810760 , Actual = 0.814863
# Predicted = 0.814313 , Actual = 0.820008
# Predicted = 0.819245 , Actual = 0.808931
# Predicted = 0.810315 , Actual = 0.808931
# Predicted = 0.809117 , Actual = 0.809520
# Predicted = 0.809466 , Actual = 0.811524
# Predicted = 0.811248 , Actual = 0.804732
# Predicted = 0.805607 , Actual = 0.812645
# Predicted = 0.811699 , Actual = 0.819236
# Predicted = 0.818225 , Actual = 0.820311
# Predicted = 0.820031 , Actual = 0.820311
# Predicted = 0.820273 , Actual = 0.816127
# Predicted = 0.816683 , Actual = 0.816160
# Predicted = 0.816230 , Actual = 0.816127
# Predicted = 0.816141 , Actual = 0.821389
# Predicted = 0.820685 , Actual = 0.819807
# Predicted = 0.819925 , Actual = 0.822707
# Predicted = 0.822334 , Actual = 0.822707
# Predicted = 0.822657 , Actual = 0.821085
# Predicted = 0.821296 , Actual = 0.817929
# Predicted = 0.818381 , Actual = 0.810373
# Predicted = 0.811446 , Actual = 0.810143
# Predicted = 0.810318 , Actual = 0.793493
# Predicted = 0.795746 , Actual = 0.791954
# Predicted = 0.792460 , Actual = 0.791954
# Predicted = 0.792022 , Actual = 0.792550
# Predicted = 0.792479 , Actual = 0.794281
# Predicted = 0.794040 , Actual = 0.797416
# Predicted = 0.796965 , Actual = 0.775645
# Predicted = 0.778500 , Actual = 0.776066
# Predicted = 0.776391 , Actual = 0.778483
# Predicted = 0.778203 , Actual = 0.778483
# Predicted = 0.778446 , Actual = 0.781494
# Predicted = 0.781086 , Actual = 0.772887
# Predicted = 0.773984 , Actual = 0.776669
# Predicted = 0.776310 , Actual = 0.779423
# Predicted = 0.779006 , Actual = 0.780671
# Predicted = 0.780448 , Actual = 0.779636
# Predicted = 0.779745 , Actual = 0.779636
# Predicted = 0.779651 , Actual = 0.781616
# Predicted = 0.781353 , Actual = 0.777817
# Predicted = 0.778290 , Actual = 0.770654
# Predicted = 0.771676 , Actual = 0.776910
# Predicted = 0.776209 , Actual = 0.777091
# Predicted = 0.776973 , Actual = 0.776699
# Predicted = 0.776736 , Actual = 0.777212
# Predicted = 0.777148 , Actual = 0.777212
# Predicted = 0.777203 , Actual = 0.781372
# Predicted = 0.780814 , Actual = 0.778180
# Predicted = 0.778533 , Actual = 0.780975
# Predicted = 0.780648 , Actual = 0.782503
# Predicted = 0.782254 , Actual = 0.784468
# Predicted = 0.784171 , Actual = 0.784468
# Predicted = 0.784428 , Actual = 0.781317
# Predicted = 0.781734 , Actual = 0.781067
# Predicted = 0.781156 , Actual = 0.789297
# Predicted = 0.788206 , Actual = 0.782258
# Predicted = 0.783056 , Actual = 0.781097
# Predicted = 0.781360 , Actual = 0.781555
# Predicted = 0.781529 , Actual = 0.781555
# Predicted = 0.781551 , Actual = 0.777635
# Predicted = 0.778160 , Actual = 0.783976
# Predicted = 0.783195 , Actual = 0.782014
# Predicted = 0.782173 , Actual = 0.776609
# Predicted = 0.777356 , Actual = 0.772171
# Predicted = 0.772866 , Actual = 0.771635
# Predicted = 0.771800 , Actual = 0.771635
# Predicted = 0.771657 , Actual = 0.771426
# Predicted = 0.771457 , Actual = 0.761644
# Predicted = 0.762960 , Actual = 0.758409
# Predicted = 0.759018 , Actual = 0.768374
# Predicted = 0.767120 , Actual = 0.763679
# Predicted = 0.764141 , Actual = 0.763913
# Predicted = 0.763944 , Actual = 0.763913
# Predicted = 0.763917 , Actual = 0.766078
# Predicted = 0.765788 , Actual = 0.761470
# Predicted = 0.762050 , Actual = 0.766195
# Predicted = 0.765638 , Actual = 0.762515
# Predicted = 0.762935 , Actual = 0.777756
# Predicted = 0.775762 , Actual = 0.777454
# Predicted = 0.777227 , Actual = 0.777454
# Predicted = 0.777423 , Actual = 0.786318
# Predicted = 0.785122 , Actual = 0.786813
# Predicted = 0.786586 , Actual = 0.783914
# Predicted = 0.784273 , Actual = 0.783177
# Predicted = 0.783324 , Actual = 0.776036
# Predicted = 0.777015 , Actual = 0.775194
# Predicted = 0.775439 , Actual = 0.775194
# Predicted = 0.775227 , Actual = 0.764614
# Predicted = 0.766039 , Actual = 0.761760
# Predicted = 0.762334 , Actual = 0.761702
# Predicted = 0.761787 , Actual = 0.757232
# Predicted = 0.757843 , Actual = 0.763942
# Predicted = 0.763124 , Actual = 0.763009
# Predicted = 0.763024 , Actual = 0.763009
# Predicted = 0.763011 , Actual = 0.762602
# Predicted = 0.762657 , Actual = 0.764994
# Predicted = 0.764680 , Actual = 0.770090
# Predicted = 0.769364 , Actual = 0.769497
# Predicted = 0.769479 , Actual = 0.767666
# Predicted = 0.767909 , Actual = 0.768285
# Predicted = 0.768235 , Actual = 0.768285
# Predicted = 0.768278 , Actual = 0.757892
# Predicted = 0.759285 , Actual = 0.763301
# Predicted = 0.762762 , Actual = 0.768935
# Predicted = 0.768106 , Actual = 0.780975
# Predicted = 0.779252 , Actual = 0.777333
# Predicted = 0.777590 , Actual = 0.778331
# Predicted = 0.778232 , Actual = 0.778331
# Predicted = 0.778318 , Actual = 0.770844
# Predicted = 0.771846 , Actual = 0.772111
# Predicted = 0.772075 , Actual = 0.777514
# Predicted = 0.776785 , Actual = 0.778513
# Predicted = 0.778282 , Actual = 0.782258
# Predicted = 0.781725 , Actual = 0.782197
# Predicted = 0.782134 , Actual = 0.782197
# Predicted = 0.782189 , Actual = 0.785639
# Predicted = 0.785177 , Actual = 0.801603
# Predicted = 0.799406 , Actual = 0.806322
# Predicted = 0.805401 , Actual = 0.789609
# Predicted = 0.791720 , Actual = 0.782871
# Predicted = 0.784049 , Actual = 0.785145
# Predicted = 0.784999 , Actual = 0.785145
# Predicted = 0.785126 , Actual = 0.784652
# Predicted = 0.784715 , Actual = 0.794913
# Predicted = 0.793554 , Actual = 0.797385
# Predicted = 0.796875 , Actual = 0.790389
# Predicted = 0.791253 , Actual = 0.793116
# Predicted = 0.792868 , Actual = 0.793399
# Predicted = 0.793328 , Actual = 0.793399
# Predicted = 0.793390 , Actual = 0.791296
# Predicted = 0.791575 , Actual = 0.798499
# Predicted = 0.797576 , Actual = 0.810767
# Predicted = 0.809014 , Actual = 0.807983
# Predicted = 0.808120 , Actual = 0.804117
# Predicted = 0.804649 , Actual = 0.803342
# Predicted = 0.803516 , Actual = 0.803342
# Predicted = 0.803365 , Actual = 0.798945
# Predicted = 0.799533 , Actual = 0.791734
# Predicted = 0.792770 , Actual = 0.787929
# Predicted = 0.788571 , Actual = 0.788799
# Predicted = 0.788769 , Actual = 0.781891
# Predicted = 0.782804 , Actual = 0.782320
# Predicted = 0.782384 , Actual = 0.782320
# Predicted = 0.782329 , Actual = 0.782718
# Predicted = 0.782666 , Actual = 0.774293
# Predicted = 0.775404 , Actual = 0.772052
# Predicted = 0.772496 , Actual = 0.764614
# Predicted = 0.765658 , Actual = 0.765961
# Predicted = 0.765921 , Actual = 0.764409
# Predicted = 0.764609 , Actual = 0.764088
# Predicted = 0.764157 , Actual = 0.760630
# Predicted = 0.761097 , Actual = 0.778240
# Predicted = 0.775965 , Actual = 0.777877
# Predicted = 0.777624 , Actual = 0.767695
# Predicted = 0.769012 , Actual = 0.762282
# Predicted = 0.763173 , Actual = 0.762515
# Predicted = 0.762602 , Actual = 0.762515
# Predicted = 0.762527 , Actual = 0.767106
# Predicted = 0.766500 , Actual = 0.767312
# Predicted = 0.767204 , Actual = 0.776096
# Predicted = 0.774919 , Actual = 0.773305
# Predicted = 0.773519 , Actual = 0.774503
# Predicted = 0.774373 , Actual = 0.773096
# Predicted = 0.773265 , Actual = 0.773096
# Predicted = 0.773118 , Actual = 0.776488
# Predicted = 0.776042 , Actual = 0.774563
# Predicted = 0.774759 , Actual = 0.766783
# Predicted = 0.767839 , Actual = 0.780366
# Predicted = 0.778703 , Actual = 0.776699
# Predicted = 0.776965 , Actual = 0.776609
# Predicted = 0.776656 , Actual = 0.776609
# Predicted = 0.776615 , Actual = 0.772768
# Predicted = 0.773279 , Actual = 0.773007
# Predicted = 0.773043 , Actual = 0.771605
# Predicted = 0.771796 , Actual = 0.774863
# Predicted = 0.774455 , Actual = 0.764438
# Predicted = 0.765770 , Actual = 0.765404
# Predicted = 0.765453 , Actual = 0.765404
# Predicted = 0.765410 , Actual = 0.771159
# Predicted = 0.770395 , Actual = 0.770505
# Predicted = 0.770490 , Actual = 0.765667
# Predicted = 0.766308 , Actual = 0.762689
# Predicted = 0.763170 , Actual = 0.752219
# Predicted = 0.753673 , Actual = 0.751682
# Predicted = 0.751946 , Actual = 0.751004
# Predicted = 0.751129 , Actual = 0.751004
# Predicted = 0.751021 , Actual = 0.743384
# Predicted = 0.744397 , Actual = 0.743329
# Predicted = 0.743471 , Actual = 0.743191
# Predicted = 0.743228 , Actual = 0.741592
# Predicted = 0.741809 , Actual = 0.744629
# Predicted = 0.744255 , Actual = 0.744518
# Predicted = 0.744483 , Actual = 0.740302
# Predicted = 0.740857 , Actual = 0.744907
# Predicted = 0.744369 , Actual = 0.737137
# Predicted = 0.738098 , Actual = 0.740988
# Predicted = 0.740604 , Actual = 0.737654
# Predicted = 0.738046 , Actual = 0.737436
# Predicted = 0.737517 , Actual = 0.737436
# Predicted = 0.737447 , Actual = 0.737681
# Predicted = 0.737650 , Actual = 0.743660
# Predicted = 0.742861 , Actual = 0.737599
# Predicted = 0.738299 , Actual = 0.737327
# Predicted = 0.737456 , Actual = 0.727352
# Predicted = 0.728696 , Actual = 0.727352
# Predicted = 0.727531 , Actual = 0.728704
# Predicted = 0.728548 , Actual = 0.728890
# Predicted = 0.728845 , Actual = 0.733837
# Predicted = 0.733173 , Actual = 0.732225
# Predicted = 0.732351 , Actual = 0.728412
# Predicted = 0.728936 , Actual = 0.731556
# Predicted = 0.731208 , Actual = 0.730594
# Predicted = 0.730676 , Actual = 0.730594
# Predicted = 0.730605 , Actual = 0.726797
# Predicted = 0.727303 , Actual = 0.739399
# Predicted = 0.737788 , Actual = 0.735916
# Predicted = 0.736165 , Actual = 0.734889
# Predicted = 0.735059 , Actual = 0.741537
# Predicted = 0.740674 , Actual = 0.741895
# Predicted = 0.741732 , Actual = 0.740796
# Predicted = 0.740921 , Actual = 0.741043
# Predicted = 0.741027 , Actual = 0.729102
# Predicted = 0.730691 , Actual = 0.737599
# Predicted = 0.736677 , Actual = 0.735510
# Predicted = 0.735666 , Actual = 0.738062
# Predicted = 0.737742 , Actual = 0.737110
# Predicted = 0.737194 , Actual = 0.737110
# Predicted = 0.737121 , Actual = 0.738525
# Predicted = 0.738337 , Actual = 0.733192
# Predicted = 0.733880 , Actual = 0.734997
# Predicted = 0.734848 , Actual = 0.734592
# Predicted = 0.734626 , Actual = 0.733272
# Predicted = 0.733453 , Actual = 0.731904
# Predicted = 0.732111 , Actual = 0.731904
# Predicted = 0.731932 , Actual = 0.720747
# Predicted = 0.722242 , Actual = 0.716127
# Predicted = 0.716942 , Actual = 0.709396
# Predicted = 0.710401 , Actual = 0.715768
# Predicted = 0.715052 , Actual = 0.715692
# Predicted = 0.715607 , Actual = 0.716512
# Predicted = 0.716391 , Actual = 0.716512
# Predicted = 0.716496 , Actual = 0.711820
# Predicted = 0.712443 , Actual = 0.704151
# Predicted = 0.705255 , Actual = 0.703680
# Predicted = 0.703890 , Actual = 0.701311
# Predicted = 0.701654 , Actual = 0.692185
# Predicted = 0.693445 , Actual = 0.691085
# Predicted = 0.691399 , Actual = 0.691085
# Predicted = 0.691127 , Actual = 0.692881
# Predicted = 0.692648 , Actual = 0.702593
# Predicted = 0.701271 , Actual = 0.702099
# Predicted = 0.701989 , Actual = 0.708617
# Predicted = 0.707737 , Actual = 0.707514
# Predicted = 0.707544 , Actual = 0.709019
# Predicted = 0.708823 , Actual = 0.712758
# Predicted = 0.712235 , Actual = 0.713852
# Predicted = 0.713637 , Actual = 0.712454
# Predicted = 0.712611 , Actual = 0.719011
# Predicted = 0.718161 , Actual = 0.716794
# Predicted = 0.716976 , Actual = 0.722752
# Predicted = 0.721984 , Actual = 0.723746
# Predicted = 0.723512 , Actual = 0.718701
# Predicted = 0.719340 , Actual = 0.713063
# Predicted = 0.713896 , Actual = 0.708567
# Predicted = 0.709274 , Actual = 0.701164
# Predicted = 0.702238 , Actual = 0.701459
# Predicted = 0.701562 , Actual = 0.701902
# Predicted = 0.701857 , Actual = 0.702741
# Predicted = 0.702624 , Actual = 0.702741
# Predicted = 0.702725 , Actual = 0.698934
# Predicted = 0.699436 , Actual = 0.699741
# Predicted = 0.699701 , Actual = 0.701213
# Predicted = 0.701013 , Actual = 0.702395
# Predicted = 0.702212 , Actual = 0.702691
# Predicted = 0.702628 , Actual = 0.706664
# Predicted = 0.706129 , Actual = 0.706664
# Predicted = 0.706593 , Actual = 0.708215
# Predicted = 0.708000 , Actual = 0.714975
# Predicted = 0.714052 , Actual = 0.720929
# Predicted = 0.720020 , Actual = 0.723066
# Predicted = 0.722664 , Actual = 0.733057
# Predicted = 0.731685 , Actual = 0.733595
# Predicted = 0.733343 , Actual = 0.733595
# Predicted = 0.733562 , Actual = 0.737300
# Predicted = 0.736807 , Actual = 0.727934
# Predicted = 0.729106 , Actual = 0.726586
# Predicted = 0.726918 , Actual = 0.733487
# Predicted = 0.732620 , Actual = 0.727114
# Predicted = 0.727842 , Actual = 0.726296
# Predicted = 0.726500 , Actual = 0.726296
# Predicted = 0.726323 , Actual = 0.726111
# Predicted = 0.726139 , Actual = 0.726507
# Predicted = 0.726458 , Actual = 0.722517
# Predicted = 0.723038 , Actual = 0.721996
# Predicted = 0.722134 , Actual = 0.722074
# Predicted = 0.722082 , Actual = 0.721839
# Predicted = 0.721871 , Actual = 0.721501
# Predicted = 0.721550 , Actual = 0.725953
# Predicted = 0.725371 , Actual = 0.721163
# Predicted = 0.721719 , Actual = 0.714286
# Predicted = 0.715268 , Actual = 0.707564
# Predicted = 0.708580 , Actual = 0.713954
# Predicted = 0.713245 , Actual = 0.713750
# Predicted = 0.713683 , Actual = 0.713750
# Predicted = 0.713741 , Actual = 0.714031
# Predicted = 0.713993 , Actual = 0.717051
# Predicted = 0.716647 , Actual = 0.714158
# Predicted = 0.714487 , Actual = 0.714796
# Predicted = 0.714755 , Actual = 0.703260
# Predicted = 0.704778 , Actual = 0.704498
# Predicted = 0.704535 , Actual = 0.704498
# Predicted = 0.704503 , Actual = 0.705144
# Predicted = 0.705059 , Actual = 0.702938
# Predicted = 0.703218 , Actual = 0.705940
# Predicted = 0.705581 , Actual = 0.711541
# Predicted = 0.710754 , Actual = 0.711440
# Predicted = 0.711349 , Actual = 0.713216
# Predicted = 0.712970 , Actual = 0.713216
# Predicted = 0.713183 , Actual = 0.708767
# Predicted = 0.709350 , Actual = 0.711845
# Predicted = 0.711516 , Actual = 0.707714
# Predicted = 0.708216 , Actual = 0.720565
# Predicted = 0.718932 , Actual = 0.723432
# Predicted = 0.722838 , Actual = 0.723772
# Predicted = 0.723649 , Actual = 0.723772
# Predicted = 0.723756 , Actual = 0.718597
# Predicted = 0.719278 , Actual = 0.724034
# Predicted = 0.723406 , Actual = 0.724664
# Predicted = 0.724498 , Actual = 0.722961
# Predicted = 0.723164 , Actual = 0.719011
# Predicted = 0.719560 , Actual = 0.719502
# Predicted = 0.719510 , Actual = 0.719502
# Predicted = 0.719503 , Actual = 0.723563
# Predicted = 0.723027 , Actual = 0.732198
# Predicted = 0.730988 , Actual = 0.731101
# Predicted = 0.731086 , Actual = 0.731101
# Predicted = 0.731099 , Actual = 0.734808
# Predicted = 0.734319 , Actual = 0.734403
# Predicted = 0.734392 , Actual = 0.734403
# Predicted = 0.734402 , Actual = 0.726691
# Predicted = 0.727708 , Actual = 0.720903
# Predicted = 0.721799 , Actual = 0.720955
# Predicted = 0.721066 , Actual = 0.730407
# Predicted = 0.729176 , Actual = 0.721553
# Predicted = 0.722559 , Actual = 0.718856
# Predicted = 0.719344 , Actual = 0.718856
# Predicted = 0.718920 , Actual = 0.724638
# Predicted = 0.723884 , Actual = 0.717412
# Predicted = 0.718266 , Actual = 0.720513
# Predicted = 0.720216 , Actual = 0.710581
# Predicted = 0.711855 , Actual = 0.719865
# Predicted = 0.718804 , Actual = 0.717283
# Predicted = 0.717485 , Actual = 0.717283
# Predicted = 0.717310 , Actual = 0.717077
# Predicted = 0.717108 , Actual = 0.722961
# Predicted = 0.722185 , Actual = 0.721970
# Predicted = 0.721999 , Actual = 0.727088
# Predicted = 0.726414 , Actual = 0.727061
# Predicted = 0.726975 , Actual = 0.728200
# Predicted = 0.728038 , Actual = 0.728200
# Predicted = 0.728178 , Actual = 0.726111
# Predicted = 0.726385 , Actual = 0.729235
# Predicted = 0.728857 , Actual = 0.728412
# Predicted = 0.728471 , Actual = 0.728306
# Predicted = 0.728328 , Actual = 0.728491
# Predicted = 0.728469 , Actual = 0.728491
# Predicted = 0.728488 , Actual = 0.728491
# Predicted = 0.728491 , Actual = 0.716281
# Predicted = 0.717899 , Actual = 0.714847
# Predicted = 0.715251 , Actual = 0.706964
# Predicted = 0.708060 , Actual = 0.702001
# Predicted = 0.702801 , Actual = 0.697301
# Predicted = 0.698027 , Actual = 0.695241
# Predicted = 0.695608 , Actual = 0.695241
# Predicted = 0.695289 , Actual = 0.698617
# Predicted = 0.698178 , Actual = 0.697350
# Predicted = 0.697459 , Actual = 0.699692
# Predicted = 0.699397 , Actual = 0.697010
# Predicted = 0.697325 , Actual = 0.687096
# Predicted = 0.688445 , Actual = 0.687498
# Predicted = 0.687623 , Actual = 0.687498
# Predicted = 0.687514 , Actual = 0.687002
# Predicted = 0.687070 , Actual = 0.692689
# Predicted = 0.691948 , Actual = 0.685895
# Predicted = 0.686694 , Actual = 0.699154
# Predicted = 0.697506 , Actual = 0.700992
# Predicted = 0.700532 , Actual = 0.702494
# Predicted = 0.702235 , Actual = 0.702494
# Predicted = 0.702460 , Actual = 0.697156
# Predicted = 0.697856 , Actual = 0.700550
# Predicted = 0.700194 , Actual = 0.707539
# Predicted = 0.706569 , Actual = 0.708316
# Predicted = 0.708085 , Actual = 0.706714
# Predicted = 0.706895 , Actual = 0.708416
# Predicted = 0.708215 , Actual = 0.708416
# Predicted = 0.708389 , Actual = 0.708240
# Predicted = 0.708260 , Actual = 0.705617
# Predicted = 0.705966 , Actual = 0.713267
# Predicted = 0.712303 , Actual = 0.722256
# Predicted = 0.720944 , Actual = 0.708567
# Predicted = 0.710204 , Actual = 0.707214
# Predicted = 0.707609 , Actual = 0.707214
# Predicted = 0.707266 , Actual = 0.709522
# Predicted = 0.709224 , Actual = 0.708215
# Predicted = 0.708348 , Actual = 0.707814
# Predicted = 0.707885 , Actual = 0.709019
# Predicted = 0.708869 , Actual = 0.709925
# Predicted = 0.709785 , Actual = 0.710631
# Predicted = 0.710519 , Actual = 0.710328
# Predicted = 0.710353 , Actual = 0.714235
# Predicted = 0.713722 , Actual = 0.709950
# Predicted = 0.710449 , Actual = 0.716949
# Predicted = 0.716089 , Actual = 0.713827
# Predicted = 0.714126 , Actual = 0.712251
# Predicted = 0.712499 , Actual = 0.715103
# Predicted = 0.714758 , Actual = 0.715103
# Predicted = 0.715057 , Actual = 0.724165
# Predicted = 0.722960 , Actual = 0.720877
# Predicted = 0.721153 , Actual = 0.717901
# Predicted = 0.718331 , Actual = 0.719891
# Predicted = 0.719685 , Actual = 0.713216
# Predicted = 0.714073 , Actual = 0.712149
# Predicted = 0.712404 , Actual = 0.712149
# Predicted = 0.712183 , Actual = 0.714796
# Predicted = 0.714450 , Actual = 0.717257
# Predicted = 0.716885 , Actual = 0.726903
# Predicted = 0.725578 , Actual = 0.736160
# Predicted = 0.734765 , Actual = 0.742942
# Predicted = 0.741867 , Actual = 0.743771
# Predicted = 0.743521 , Actual = 0.743771
# Predicted = 0.743738 , Actual = 0.746491
# Predicted = 0.746129 , Actual = 0.744158
# Predicted = 0.744417 , Actual = 0.752021
# Predicted = 0.751021 , Actual = 0.744158
# Predicted = 0.745062 , Actual = 0.757662
# Predicted = 0.755998 , Actual = 0.758035
# Predicted = 0.757766 , Actual = 0.758035
# Predicted = 0.758000 , Actual = 0.751061
# Predicted = 0.751977 , Actual = 0.745295
# Predicted = 0.746175 , Actual = 0.743246
# Predicted = 0.743632 , Actual = 0.764088
# Predicted = 0.761389 , Actual = 0.761064
# Predicted = 0.761107 , Actual = 0.760398
# Predicted = 0.760492 , Actual = 0.760398
# Predicted = 0.760410 , Actual = 0.758323
# Predicted = 0.758598 , Actual = 0.761789
# Predicted = 0.761368 , Actual = 0.753381
# Predicted = 0.754436 , Actual = 0.751908
# Predicted = 0.752242 , Actual = 0.751287
# Predicted = 0.751413 , Actual = 0.750835
# Predicted = 0.750911 , Actual = 0.750835
# Predicted = 0.750845 , Actual = 0.754006
# Predicted = 0.753589 , Actual = 0.761296
# Predicted = 0.760279 , Actual = 0.766372
# Predicted = 0.765570 , Actual = 0.767489
# Predicted = 0.767236 , Actual = 0.768079
# Predicted = 0.767968 , Actual = 0.767843
# Predicted = 0.767859 , Actual = 0.767077
# Predicted = 0.767180 , Actual = 0.762166
# Predicted = 0.762826 , Actual = 0.752078
# Predicted = 0.753491 , Actual = 0.759878
# Predicted = 0.759037 , Actual = 0.750779
# Predicted = 0.751868 , Actual = 0.755059
# Predicted = 0.754638 , Actual = 0.755715
# Predicted = 0.755573 , Actual = 0.755715
# Predicted = 0.755696 , Actual = 0.760023
# Predicted = 0.759452 , Actual = 0.766812
# Predicted = 0.765841 , Actual = 0.764848
# Predicted = 0.764979 , Actual = 0.770594
# Predicted = 0.769853 , Actual = 0.771873
# Predicted = 0.771607 , Actual = 0.771337
# Predicted = 0.771373 , Actual = 0.771337
# Predicted = 0.771342 , Actual = 0.774863
# Predicted = 0.774399 , Actual = 0.781097
# Predicted = 0.780214 , Actual = 0.781494
# Predicted = 0.781325 , Actual = 0.774084
# Predicted = 0.775038 , Actual = 0.770564
# Predicted = 0.771153 , Actual = 0.771129
# Predicted = 0.771132 , Actual = 0.771129
# Predicted = 0.771129 , Actual = 0.771647
# Predicted = 0.771579 , Actual = 0.774383
# Predicted = 0.774014 , Actual = 0.759850
# Predicted = 0.761717 , Actual = 0.764672
# Predicted = 0.764282 , Actual = 0.759446
# Predicted = 0.760084 , Actual = 0.760485
# Predicted = 0.760432 , Actual = 0.760485
# Predicted = 0.760478 , Actual = 0.766313
# Predicted = 0.765543 , Actual = 0.750244
# Predicted = 0.752268 , Actual = 0.745684
# Predicted = 0.746552 , Actual = 0.746408
# Predicted = 0.746427 , Actual = 0.736187
# Predicted = 0.737538 , Actual = 0.736730
# Predicted = 0.736837 , Actual = 0.736730
# Predicted = 0.736744 , Actual = 0.731154
# Predicted = 0.731892 , Actual = 0.735159
# Predicted = 0.734728 , Actual = 0.739290
# Predicted = 0.738688 , Actual = 0.732064
# Predicted = 0.732939 , Actual = 0.727511
# Predicted = 0.728227 , Actual = 0.730007
# Predicted = 0.729772 , Actual = 0.730007
# Predicted = 0.729976 , Actual = 0.728863
# Predicted = 0.729010 , Actual = 0.733756
# Predicted = 0.733130 , Actual = 0.729661
# Predicted = 0.730119 , Actual = 0.722308
# Predicted = 0.723339 , Actual = 0.722596
# Predicted = 0.722694 , Actual = 0.722517
# Predicted = 0.722540 , Actual = 0.723406
# Predicted = 0.723292 , Actual = 0.722204
# Predicted = 0.722348 , Actual = 0.717360
# Predicted = 0.718018 , Actual = 0.719632
# Predicted = 0.719419 , Actual = 0.721605
# Predicted = 0.721317 , Actual = 0.718649
# Predicted = 0.719001 , Actual = 0.719399
# Predicted = 0.719346 , Actual = 0.718494
# Predicted = 0.718607 , Actual = 0.718597
# Predicted = 0.718598 , Actual = 0.723301
# Predicted = 0.722680 , Actual = 0.725242
# Predicted = 0.724904 , Actual = 0.722596
# Predicted = 0.722901 , Actual = 0.734997
# Predicted = 0.733400 , Actual = 0.725900
# Predicted = 0.726892 , Actual = 0.725900
# Predicted = 0.726031 , Actual = 0.736648
# Predicted = 0.735242 , Actual = 0.744796
# Predicted = 0.743535 , Actual = 0.746798
# Predicted = 0.746368 , Actual = 0.743743
# Predicted = 0.744089 , Actual = 0.737463
# Predicted = 0.738337 , Actual = 0.740001
# Predicted = 0.739781 , Actual = 0.740001
# Predicted = 0.739972 , Actual = 0.739044
# Predicted = 0.739166 , Actual = 0.736052
# Predicted = 0.736463 , Actual = 0.741098
# Predicted = 0.740486 , Actual = 0.736079
# Predicted = 0.736661 , Actual = 0.739508
# Predicted = 0.739132 , Actual = 0.739618
# Predicted = 0.739554 , Actual = 0.739618
# Predicted = 0.739610 , Actual = 0.745657
# Predicted = 0.744858 , Actual = 0.746519
# Predicted = 0.746300 , Actual = 0.749288
# Predicted = 0.748893 , Actual = 0.759648
# Predicted = 0.758229 , Actual = 0.748744
# Predicted = 0.749998 , Actual = 0.748867
# Predicted = 0.749017 , Actual = 0.748867
# Predicted = 0.748887 , Actual = 0.733434
# Predicted = 0.735478 , Actual = 0.736269
# Predicted = 0.736164 , Actual = 0.742501
# Predicted = 0.741663 , Actual = 0.743246
# Predicted = 0.743037 , Actual = 0.748699
# Predicted = 0.747950 , Actual = 0.749991
# Predicted = 0.749721 , Actual = 0.749991
# Predicted = 0.749955 , Actual = 0.753949
# Predicted = 0.753421 , Actual = 0.745935
# Predicted = 0.746925 , Actual = 0.749738
# Predicted = 0.749366 , Actual = 0.747943
# Predicted = 0.748131 , Actual = 0.755829
# Predicted = 0.754810 , Actual = 0.756974
# Predicted = 0.756688 , Actual = 0.756974
# Predicted = 0.756936 , Actual = 0.753211
# Predicted = 0.753704 , Actual = 0.764263
# Predicted = 0.762864 , Actual = 0.761557
# Predicted = 0.761730 , Actual = 0.763621
# Predicted = 0.763370 , Actual = 0.759590
# Predicted = 0.760091 , Actual = 0.757892
# Predicted = 0.758183 , Actual = 0.757892
# Predicted = 0.757931 , Actual = 0.759532
# Predicted = 0.759320 , Actual = 0.750441
# Predicted = 0.751618 , Actual = 0.747999
# Predicted = 0.748478 , Actual = 0.748722
# Predicted = 0.748690 , Actual = 0.745573
# Predicted = 0.745986 , Actual = 0.746547
# Predicted = 0.746473 , Actual = 0.746547
# Predicted = 0.746537 , Actual = 0.746854
# Predicted = 0.746812 , Actual = 0.751343
# Predicted = 0.750743 , Actual = 0.746519
# Predicted = 0.747079 , Actual = 0.750920
# Predicted = 0.750411 , Actual = 0.759532
# Predicted = 0.758324 , Actual = 0.759676
# Predicted = 0.759497 , Actual = 0.759676
# Predicted = 0.759652 , Actual = 0.756573
# Predicted = 0.756981 , Actual = 0.760427
# Predicted = 0.759970 , Actual = 0.758697
# Predicted = 0.758866 , Actual = 0.762980
# Predicted = 0.762435 , Actual = 0.762050
# Predicted = 0.762101 , Actual = 0.761963
# Predicted = 0.761981 , Actual = 0.761963
# Predicted = 0.761965 , Actual = 0.765726
# Predicted = 0.765228 , Actual = 0.766842
# Predicted = 0.766628 , Actual = 0.772320
# Predicted = 0.771566 , Actual = 0.770564
# Predicted = 0.770697 , Actual = 0.764994
# Predicted = 0.765749 , Actual = 0.764643
# Predicted = 0.764789 , Actual = 0.764643
# Predicted = 0.764662 , Actual = 0.768197
# Predicted = 0.767729 , Actual = 0.770475
# Predicted = 0.770111 , Actual = 0.762980
# Predicted = 0.763925 , Actual = 0.768403
# Predicted = 0.767809 , Actual = 0.761644
# Predicted = 0.762462 , Actual = 0.762515
# Predicted = 0.762508 , Actual = 0.762602
# Predicted = 0.762590 , Actual = 0.762457
# Predicted = 0.762475 , Actual = 0.763184
# Predicted = 0.763090 , Actual = 0.761025
# Predicted = 0.761299 , Actual = 0.761180
# Predicted = 0.761196 , Actual = 0.758956
# Predicted = 0.759253 , Actual = 0.762515
# Predicted = 0.762082 , Actual = 0.756287
# Predicted = 0.757056 , Actual = 0.757834
# Predicted = 0.757731 , Actual = 0.750554
# Predicted = 0.751507 , Actual = 0.751597
# Predicted = 0.751585 , Actual = 0.755660
# Predicted = 0.755119 , Actual = 0.756344
# Predicted = 0.756181 , Actual = 0.756974
# Predicted = 0.756869 , Actual = 0.757060
# Predicted = 0.757035 , Actual = 0.758604
# Predicted = 0.758396 , Actual = 0.768167
# Predicted = 0.766870 , Actual = 0.766871
# Predicted = 0.766871 , Actual = 0.764643
# Predicted = 0.764939 , Actual = 0.754774
# Predicted = 0.756122 , Actual = 0.753892
# Predicted = 0.754188 , Actual = 0.752502
# Predicted = 0.752725 , Actual = 0.746854
# Predicted = 0.747632 , Actual = 0.747077
# Predicted = 0.747151 , Actual = 0.747580
# Predicted = 0.747523 , Actual = 0.750976
# Predicted = 0.750518 , Actual = 0.748559
# Predicted = 0.748819 , Actual = 0.749288
# Predicted = 0.749226 , Actual = 0.749176
# Predicted = 0.749183 , Actual = 0.754290
# Predicted = 0.753613 , Actual = 0.754205
# Predicted = 0.754127 , Actual = 0.758006
# Predicted = 0.757492 , Actual = 0.764000
# Predicted = 0.763138 , Actual = 0.761470
# Predicted = 0.761691 , Actual = 0.762369
# Predicted = 0.762279 , Actual = 0.762369
# Predicted = 0.762357 , Actual = 0.764029
# Predicted = 0.763808 , Actual = 0.766577
# Predicted = 0.766210 , Actual = 0.767048
# Predicted = 0.766937 , Actual = 0.763796
# Predicted = 0.764212 , Actual = 0.766577
# Predicted = 0.766264 , Actual = 0.765961
# Predicted = 0.766001 , Actual = 0.765931
# Predicted = 0.765940 , Actual = 0.766489
# Predicted = 0.766416 , Actual = 0.761354
# Predicted = 0.762025 , Actual = 0.762137
# Predicted = 0.762122 , Actual = 0.757805
# Predicted = 0.758377 , Actual = 0.756916
# Predicted = 0.757110 , Actual = 0.758380
# Predicted = 0.758212 , Actual = 0.760774
# Predicted = 0.760435 , Actual = 0.753494
# Predicted = 0.754414 , Actual = 0.756916
# Predicted = 0.756584 , Actual = 0.757404
# Predicted = 0.757295 , Actual = 0.762747
# Predicted = 0.762024 , Actual = 0.761702
# Predicted = 0.761745 , Actual = 0.761731
# Predicted = 0.761733 , Actual = 0.762486
# Predicted = 0.762386 , Actual = 0.767254
# Predicted = 0.766609 , Actual = 0.772290
# Predicted = 0.771538 , Actual = 0.763213
# Predicted = 0.764317 , Actual = 0.759994
# Predicted = 0.760567 , Actual = 0.760572
# Predicted = 0.760571 , Actual = 0.760572
# Predicted = 0.760572 , Actual = 0.759965
# Predicted = 0.760045 , Actual = 0.764883
# Predicted = 0.764242 , Actual = 0.765257
# Predicted = 0.765123 , Actual = 0.759215
# Predicted = 0.759998 , Actual = 0.758783
# Predicted = 0.758944 , Actual = 0.759821
# Predicted = 0.759705 , Actual = 0.758840
# Predicted = 0.758955 , Actual = 0.760341
# Predicted = 0.760157 , Actual = 0.764175
# Predicted = 0.763643 , Actual = 0.767489
# Predicted = 0.766980 , Actual = 0.767548
# Predicted = 0.767473 , Actual = 0.767725
# Predicted = 0.767692 , Actual = 0.767371
# Predicted = 0.767413 , Actual = 0.767636
# Predicted = 0.767607 , Actual = 0.769853
# Predicted = 0.769556 , Actual = 0.773096
# Predicted = 0.772627 , Actual = 0.767283
# Predicted = 0.767991 , Actual = 0.759532
# Predicted = 0.760651 , Actual = 0.755287
# Predicted = 0.755995 , Actual = 0.755316
# Predicted = 0.755406 , Actual = 0.755316
# Predicted = 0.755328 , Actual = 0.754148
# Predicted = 0.754304 , Actual = 0.753750
# Predicted = 0.753823 , Actual = 0.748951
# Predicted = 0.749595 , Actual = 0.745712
# Predicted = 0.746225 , Actual = 0.734187
# Predicted = 0.735774 , Actual = 0.734187
# Predicted = 0.734396 , Actual = 0.733837
# Predicted = 0.733911 , Actual = 0.735537
# Predicted = 0.735323 , Actual = 0.738907
# Predicted = 0.738435 , Actual = 0.738689
# Predicted = 0.738655 , Actual = 0.741372
# Predicted = 0.741014 , Actual = 0.742694
# Predicted = 0.742473 , Actual = 0.744518
# Predicted = 0.744249 , Actual = 0.743716
# Predicted = 0.743786 , Actual = 0.747831
# Predicted = 0.747298 , Actual = 0.746436
# Predicted = 0.746550 , Actual = 0.738662
# Predicted = 0.739701 , Actual = 0.741125
# Predicted = 0.740937 , Actual = 0.744546
# Predicted = 0.744071 , Actual = 0.745796
# Predicted = 0.745569 , Actual = 0.745045
# Predicted = 0.745114 , Actual = 0.747692
# Predicted = 0.747352 , Actual = 0.745601
# Predicted = 0.745832 , Actual = 0.747680
# Predicted = 0.747436 , Actual = 0.744602
# Predicted = 0.744976 , Actual = 0.744158
# Predicted = 0.744266 , Actual = 0.745184
# Predicted = 0.745063 , Actual = 0.744990
# Predicted = 0.745000 , Actual = 0.748951
# Predicted = 0.748430 , Actual = 0.749681
# Predicted = 0.749516 , Actual = 0.751654
# Predicted = 0.751372 , Actual = 0.733999
# Predicted = 0.736290 , Actual = 0.730567
# Predicted = 0.731319 , Actual = 0.729714
# Predicted = 0.729925 , Actual = 0.729714
# Predicted = 0.729742 , Actual = 0.726533
# Predicted = 0.726955 , Actual = 0.725058
# Predicted = 0.725307 , Actual = 0.724506
# Predicted = 0.724611 , Actual = 0.721553
# Predicted = 0.721955 , Actual = 0.717618
# Predicted = 0.718188 , Actual = 0.719114
# Predicted = 0.718992 , Actual = 0.719114
# Predicted = 0.719098 , Actual = 0.719735
# Predicted = 0.719651 , Actual = 0.718701
# Predicted = 0.718826 , Actual = 0.718494
# Predicted = 0.718538 , Actual = 0.721839
# Predicted = 0.721405 , Actual = 0.723197
# Predicted = 0.722962 , Actual = 0.720825
# Predicted = 0.721106 , Actual = 0.720825

# %% [markdown]
# ### expln
# Evaluating the model with the following metrics such as percentage of r2 score , mean squared error , root mean squared error , mean absolute error and mean absolute percentage error for the predicted value and test data.

# %%
#print('Evaluation Result for Test data : ','\n')
print('R2 Score for Test data : {0:.2f} %'.format(100*r2_score(test,prediction)),'\n')
print('Mean Squared Error : ',mean_squared_error(test,prediction),'\n')
print('Mean Absolute Error : ',mean_absolute_error(test,prediction),'\n')
print('Root Mean Squared Error : ',sqrt(mean_squared_error(test,prediction)),'\n')
print('Mean Absolute Percentage Error : {0:.2f} %'.format(100*mean_absolute_percentage_error(test,prediction)))
# Out:
# R2 Score for Test data : 99.59 %
#
# Mean Squared Error :  4.960819187480288e-05
#
# Mean Absolute Error :  0.003327253882545641
#
# Root Mean Squared Error :  0.007043308304682032
#
# Mean Absolute Percentage Error : 0.40 %

# %%
#Making the predicted value as series and index as same as Test Data index since the prediction is based on test data

# %%
predictions_df = pd.Series(prediction, index = test.index)

# %%
# Convert df_week's values to a 1D array or list
# if it's a dataframe:
#df_week_values = df_week['Ex_rate'].values # Replace 'relevant_column'

# if it's already a numpy array, convert it to list
# df_week_values = df_week.tolist()


plt.rcParams['figure.figsize'] = (12,6)
fig, ax = plt.subplots()
ax.set(title='Foreign Exchange Rate Prediction, Euro to USD', xlabel='Date', ylabel='Foreign Exchange Rate')

# plot the values against their index
ax.plot(df_week.index, df_week_values, 'o', label='Actual') # Use df_week.index for x-axis

ax.plot(predictions_df, 'r', label='forecast')
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')

# %%
plt.rcParams['figure.figsize'] = (12,6)
fig, ax = plt.subplots()
ax.set(title='Foreign Exchange Rate Prediction, Euro to USD', xlabel='Date', ylabel='Foreign Exchange Rate')
ax.plot(df_week['Ex_rate'], Final_data['Predicted Exchange Rate'], 'o', label='Actual')
ax.plot(predictions_df, 'r', label='forecast')
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
